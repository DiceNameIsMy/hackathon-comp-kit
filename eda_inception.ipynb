# %%
import main

# %%
idx = 3
d, doutput, aoutput = decontextualize_then_atomize(
    data[idx]["news_text"],
    data[idx]["source"],
    len(data[idx]["claims"]),
)
# Out:
# [Chybějící kontext: článek nebyl dodán, nelze ověřit fakta ani upřesnit odkazy.]

# %%
print(aoutput.output_text)
# Out:
# ExpectedClaims: 8
# FinalClaimCount: 0
#
# CandidateClaims:
# *(žádné – ve vstupu není žádný obsah komentáře kromě metapoznámky o chybějícím kontextu)*
#
# NonClaimItems:
# 1) "[Chybějící kontext: článek nebyl dodán, nelze ověřit fakta ani upřesnit odkazy.]"
#
# ReconciliationNotes:
# - Ve vstupu není žádný věcný komentář k rozdělení na tvrzení; je uvedena pouze metainformace o chybějícím kontextu, což není atomární tvrzení k posuzovanému obsahu.
#
# FinalClaims:
# *(žádné)*
#
# ExactMatchPossible: false
# Reason: "Komentář neobsahuje žádné hodnotitelné propozice; pouze metatext o chybějícím kontextu. Vytvoření 8 tvrzení by vyžadovalo vymýšlení obsahu."
# ClosestFeasibleClaimCount: 0

# %%
print_readable(data[4]["source"])
# Out:
# Bratia Cesi, ktore noviny su to u vas?\nU nas je to DennikN, ktore vlastni ESSET
#  a ten je pod kontrolou CIA. Potom noviny SME, kde je vlastnikom Soros.
